# %%
import pandas as pd

# %%
df=pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.groupby(['Branch','City']).count()
# Out:
#                   Invoice ID  Customer type  Gender  Product line  Unit price  \
# Branch City
# A      Yangon            340            340     340           340         340
# B      Mandalay          332            332     332           332         332
# C      Naypyitaw         328            328     328           328         328
#
#                   Quantity  Tax 5%  Total  Date  Time  Payment  cogs  \
# Branch City
# A      Yangon          340     340    340   340   340      340   340
# B      Mandalay        332     332    332   332   332      332   332
# C      Naypyitaw       328     328    328   328   328      328   328
#
#                   gross margin percentage  gross income  Rating
# Branch City
# A      Yangon                         340           340     340
# B      Mandalay                       332           332     332
# C      Naypyitaw                      328           328     328

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df['date']=pd.to_datetime(df['Date'])

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.groupby('Date')['Invoice ID'].count().reset_index().sort_values('Invoice ID',ascending=False)
# Out:
#          Date  Invoice ID
# 37 2019-02-07          20
# 45 2019-02-15          19
# 60 2019-03-02          18
# 7  2019-01-08          18
# 72 2019-03-14          18
# ..        ...         ...
# 31 2019-02-01           6
# 79 2019-03-21           6
# 58 2019-02-28           6
# 3  2019-01-04           6
# 51 2019-02-21           6
#
# [89 rows x 2 columns]

# %%
df[df['Rating']==df['Rating'].max()]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 60   285-68-5083      C  Naypyitaw        Member  Female
# 62   347-34-2234      B   Mandalay        Member  Female
# 159  423-57-2993      B   Mandalay        Normal    Male
# 387  725-56-0833      A     Yangon        Normal  Female
# 853  866-70-2814      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 60        Sports and travel       24.74         3   3.7110   77.9310
# 62        Sports and travel       55.07         9  24.7815  520.4115
# 159       Sports and travel       93.39         6  28.0170  588.3570
# 387       Health and beauty       32.32        10  16.1600  339.3600
# 853  Electronic accessories       52.79        10  26.3950  554.2950
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 60  2019-02-15  17:47  Credit card   74.22                 4.761905
# ...

# %%
df.groupby('Payment')['Invoice ID'].count()
# Out:
# Payment
# Cash           344
# Credit card    311
# Ewallet        345
# Name: Invoice ID, dtype: int64

# %%
df['Invoice ID'].count()
# Out:
# 1000

# %%
df['Invoice ID'].nunique()
# Out:
# 1000

# %%
df.drop_duplicates(subset=['City'])
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 9      Food and beverages       54.84         3   8.2260  172.7460 2019-02-20
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 9  13:27  Credit card  164.52                 4.761905        8.2260     5.9

# %%
df[df['Rating']==df['Rating'].min()]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 72   510-95-6347      B   Mandalay        Member  Female
# 85   730-50-9884      C  Naypyitaw        Normal  Female
# 226  836-82-5858      B   Mandalay        Member    Male
# 328  730-61-8757      B   Mandalay        Member    Male
# 379  182-69-8360      B   Mandalay        Normal  Female
# 618  828-46-6863      A     Yangon        Member    Male
# 643  131-15-8856      C  Naypyitaw        Member  Female
# 672  576-31-4774      B   Mandalay        Normal  Female
# 790  651-96-5970      A     Yangon        Normal    Male
# 848  845-94-6841      C  Naypyitaw        Member  Female
# 876  885-56-0389      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 72       Food and beverages       48.52         3   7.2780  152.8380
# 85        Sports and travel       83.06         7  29.0710  610.4910
# 226       Health and beauty       69.37         9  31.2165  655.5465
# ...

# %%
df.groupby('Gender').size()
# Out:
# Gender
# Female    501
# Male      499
# dtype: int64

# %%
df.groupby('Branch')['cogs'].sum().reset_index().sort_values('cogs',ascending=False)
# Out:
#   Branch       cogs
# 2      C  105303.53
# 0      A  101143.21
# 1      B  101140.64

# %%
df.groupby('Product line')['Invoice ID'].count()
# Out:
# Product line
# Electronic accessories    170
# Fashion accessories       178
# Food and beverages        174
# Health and beauty         152
# Home and lifestyle        160
# Sports and travel         166
# Name: Invoice ID, dtype: int64

# %%
df['Year']=df['Date'].dt.year

# %%
df['Month']=df['Date'].dt.month

# %%
df.groupby('Month')['cogs'].sum()
# Out:
# Month
# 1    110754.16
# 2     92589.88
# 3    104243.34
# Name: cogs, dtype: float64

# %%
df['Customer type'].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
df.groupby('Customer type')['Invoice ID'].count()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: Invoice ID, dtype: int64

# %%
df['Branch']+' '+df['City']
# Out:
# 0         A Yangon
# 1      C Naypyitaw
# 2         A Yangon
# 3         A Yangon
# 4         A Yangon
#           ...
# 995    C Naypyitaw
# 996     B Mandalay
# 997       A Yangon
# 998       A Yangon
# 999       A Yangon
# Length: 1000, dtype: object
